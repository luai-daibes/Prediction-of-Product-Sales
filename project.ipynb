# %% [markdown]
# <a href="https://colab.research.google.com/github/luai-daibes/Prediction-of-Product-Sales/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
fpath ="/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week01/Data/sales_predictions_2023.csv"
df=pd.read_csv(fpath)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# make Histograms to view the distributions of numerical features in your dataset
df.hist(figsize=(12,8))
# Out:
# array([[<Axes: title={'center': 'Item_Weight'}>,
#         <Axes: title={'center': 'Item_Visibility'}>],
#        [<Axes: title={'center': 'Item_MRP'}>,
#         <Axes: title={'center': 'Outlet_Establishment_Year'}>],
#        [<Axes: title={'center': 'Item_Outlet_Sales'}>, <Axes: >]],
#       dtype=object)

# %%
# Boxplots to view statistical summaries of numerical features in your dataset
df.boxplot(figsize=(12,8))
# Out:
# <Axes: >

# %%
# Countplots to view the frequency of each class of categorial features in your dataset
df.plot(kind='bar',figsize=(15,15))
# Out:
# <Axes: >

# %%
# make  Heatmap to view the correlation between features
df.select_dtypes(include=np.number).corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027141
# Item_Visibility              -0.014048         1.000000 -0.001315
# Item_MRP                      0.027141        -0.001315  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005020
# Item_Outlet_Sales             0.014123        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
# heatmap for correlation between features
df.select_dtypes(include=np.number).corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_0e541_row0_col0, #T_0e541_row1_col1, #T_0e541_row2_col2, #T_0e541_row3_col3, #T_0e541_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0e541_row0_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_0e541_row0_col2, #T_0e541_row4_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_0e541_row0_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_0e541_row0_col4 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_0e541_row1_col0, #T_0e541_row1_col2, #T_0e541_row1_col3, #T_0e541_row1_col4, #T_0e541_row3_col0, #T_0e541_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0e541_row2_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_0e541_row2_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_0e541_row2_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_0e541_row2_col4 {
#   background-color: #f3c7b1;
# ...
